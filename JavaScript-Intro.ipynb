# %%
ijsconsole
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d6fef6d0f916> in <module>()
# ----> 1 ijsconsole
#
# NameError: name 'ijsconsole' is not defined

# %%
https://github.com/n-riesco/ijavascript

# %%
var os = require('os')
os(hostname)

# %%
# %%javascript
# max = 24;
# counts = new Int32Array(max + 1);
# limit = 105000;
#
# function randInt(max) {
#   return Math.floor(Math.random() * (max + 1));
# }

# %%
max = 4;
counts = new Int32Array(max + 1);
limit = 100000;

function randInt(max) {
  return Math.floor(Math.random() * (max + 1));
}
# Out:
# 100000

# %%
var fs = require('fs');
 
 
if (process.argv.length <= 2) {
    console.log("Usage: " + __filename + " JavaScript");
    process.exit(-1);
}
 
var path = process.argv[2];
 
fs.readdir(path, function(err, items) {
    console.log(items);
 
    for (var i=0; i<items.length; i++) {
        console.log(items[i]);
    }
});
# Out:
# Usage: [eval] JavaScript

# %%
fs.readdir(path, function(err, items) {
    console.log(items);

    for (var i=0; i<items.length; i++) {
        console.log(items[i]);
    }
});

# %%
__dirname

# %%
var dir = loc.substring(0, loc.lastIndexOf('/'));
# Out:
# evalmachine.<anonymous>:2
# var dir = loc.substring(0, loc.lastIndexOf('/'));
#              ^
# TypeError: Cannot read property 'substring' of undefined
#     at evalmachine.<anonymous>:2:14
#     at Object.exports.runInThisContext (vm.js:54:17)
#     at run ([eval]:617:19)
#     at onRunRequest ([eval]:388:22)
#     at onMessage ([eval]:356:17)
#     at emitTwo (events.js:106:13)
#     at process.emit (events.js:191:7)
#     at process.nextTick (internal/child_process.js:719:12)
#     at _combinedTickCallback (internal/process/next_tick.js:67:7)
#     at process._tickCallback (internal/process/next_tick.js:98:9)

# %%
# !locate /threejs/__init__.py

# %%
import ThreeJS
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-5-9595401e8333> in <module>()
# ----> 1 import ThreeJS
#
# ImportError: No module named ThreeJS

# %%
# !ls
# Out:
# evalmachine.<anonymous>:1
# !ls
#  ^
# ReferenceError: ls is not defined
#     at evalmachine.<anonymous>:1:2
#     at Object.exports.runInThisContext (vm.js:54:17)
#     at run ([eval]:617:19)
#     at onRunRequest ([eval]:388:22)
#     at onMessage ([eval]:356:17)
#     at emitTwo (events.js:106:13)
#     at process.emit (events.js:191:7)
#     at process.nextTick (internal/child_process.js:719:12)
#     at _combinedTickCallback (internal/process/next_tick.js:67:7)
#     at process._tickCallback (internal/process/next_tick.js:98:9)

# %%
import pythreejs
help(pythreejs)
# Out:
# Help on package pythreejs:
#
# NAME
#     pythreejs
#
# FILE
#     /home/jack/anaconda2/lib/python2.7/site-packages/pythreejs/__init__.py
#
# PACKAGE CONTENTS
#     _package
#     _version
#     install
#     pythreejs
#     sage
#
# CLASSES
#     ipywidgets.widgets.domwidget.DOMWidget(ipywidgets.widgets.widget.Widget)
#         pythreejs.pythreejs.Renderer
#     ipywidgets.widgets.widget.Widget(traitlets.config.configurable.LoggingConfigurable)
#         pythreejs.pythreejs.Controls
#             pythreejs.pythreejs.FlyControls
#             pythreejs.pythreejs.OrbitControls
#             pythreejs.pythreejs.Picker
#             pythreejs.pythreejs.TrackballControls
#         pythreejs.pythreejs.Effect
#             pythreejs.pythreejs.AnaglyphEffect
#         pythreejs.pythreejs.Geometry
#             pythreejs.pythreejs.BoxGeometry
#             pythreejs.pythreejs.CircleGeometry
#             pythreejs.pythreejs.CylinderGeometry
#             pythreejs.pythreejs.FaceGeometry
# ...

# %%
import pythreejs
pythreejs.outerdiv() << (pythreejs.initscene() <<
    [
        pythreejs.mesh(0.0, 0.0, 0.0) <<
        [
            pythreejs.box(1.0,1.0,1.0),
            pythreejs.material(Dict(:kind=>"lambert",:color=>"red"))
        ],
        pythreejs.pointlight(3.0, 3.0, 3.0),
        pythreejs.camera(0.0, 0.0, 10.0)
    ])
# Out:
#   File "<ipython-input-14-e65d3015b795>", line 7
#     pythreejs.material(Dict(:kind=>"lambert",:color=>"red"))
#                             ^
# SyntaxError: invalid syntax
